# %%
import pandas as pd

# %%
df = pd.read_csv("./merged_outputs_versions.csv", usecols=["name_v_paper", "name_v_my"])
df
# Out:
#        name_v_paper      name_v_my
# 0       NC_007636.1    NC_007636.1
# 1       NC_030928.1    NC_030928.1
# 2       NC_030937.1    NC_030937.1
# 3       NC_041844.1    NC_041844.1
# 4       NC_041845.1    NC_041845.1
# ...             ...            ...
# 1714  NZ_CP054479.1  NZ_CP054479.1
# 1715  NZ_CP054912.1  NZ_CP054912.1
# 1716  NZ_CP054913.1  NZ_CP054913.1
# 1717  NZ_CP055142.1  NZ_CP055142.1
# 1718  NZ_CP056119.1  NZ_CP056119.1
#
# [1719 rows x 2 columns]

# %%
diff  = df[df["name_v_paper"] != df["name_v_my"]]
diff
# Out:
#        name_v_paper      name_v_my
# 76      NC_041918.1    NC_041918.2
# 397     NC_047776.1    NC_047776.2
# 650     NC_048048.1    NC_048048.2
# 1222  NZ_CP028783.1  NZ_CP028783.2
# 1347  NZ_CP033396.1  NZ_CP033396.2
